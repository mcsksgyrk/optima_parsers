# %%
from parsers import *
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../../reactionsICs_w_species.xlsx', header=None,
                   sheet_name='ics', usecols="A:B")
bounds = generateBounds(df)
species = getSpecies('reaction_test.csv')

# %%
# Out:
# array(['AC', 'AC_Ga', 'AC_Gaa', 'AKT', 'AKTa', 'AMP', 'AMPK', 'AMPKa',
#        'ATF4', 'ATF4a', 'ATG5', 'ATG5_BCL2', 'ATG5t', 'ATP', 'ATP_REF',
#        'AUT', 'BCL2', 'BCL2_Bax', 'BCL2p', 'BEC1', 'BEC1_BCL2',
#        'BEC1_UVG', 'BEC1c', 'Bax', 'Baxa', 'Bid', 'CCH', 'Ca2er', 'Ca2ic',
#        'CaMKKb', 'CaMKKba', 'Calpain', 'Calpaina', 'DAPK', 'DAPKa',
#        'DRAM', 'EPAC', 'EPACa', 'G', 'GPCRa', 'Ga', 'Gaa', 'Gabg', 'Gbg',
#        'IP', 'IP2', 'IP3', 'IP3R', 'IP3R_BCL2', 'IP3R_IP3', 'Ins',
#        'Insulin', 'JNK', 'JNKa', 'MAPK15', 'MAPK15a', 'Mdm2', 'PCLe',
#        'PERK', 'PERKa', 'PI3K', 'PI3Ka', 'PIP2', 'PKA', 'PKAa', 'PLCe',
#        'PLCea', 'PUMA', 'PUMA_BCL2', 'RAP', 'REF', 'RHEB', 'RHEBa',
#        'SERCA', 'SERCAa', 'TFEB', 'TFEBi', 'TG', 'TG_SERCA', 'TSC',
#        'TSCa', 'TUN', 'ULK', 'ULKa', 'UVG', 'UVG_Bax', 'cAMP', 'caspase',
#        'caspasea', 'cytc', 'dS', 'eS', 'mTOR', 'mTOR_RAP', 'mTORa',
#        'mTORa_ULK', 'mTORa_ULKa', 'nS', 'nS_ina', 'p53_BCL2', 'p53a',
#        'p53c', 'p53m', 'phag', 'preAUT', 'tBid'], dtype='<U10')
